# %%
from PokemonCardManager import *
from MarkowitzPortfolioOptimizer import MarkowitzOptimizer
from UsefulFunctionsForModels import get_dataframe_cards_matrix
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
api=PokemonCardAPI()
data=PokemonCardDatabase(api)
data.update_database("datas")
# Out:
# Importing cards:  81%|████████▏ | 61/75 [07:18<01:40,  7.19s/it]
# Erreur: 404
# ...
# Saving files: 100%|██████████| 2/2 [00:00<00:00, 39.60it/s]
# Database updated successfully with 3345 cards.
#                   id                  name        rarity  \
# 0              dp3-1              Ampharos     Rare Holo
# 1             ex12-1            Aerodactyl     Rare Holo
# 3              ex7-1             Azumarill     Rare Holo
# 4              sm9-1  Celebi & Venusaur-GX  Rare Holo GX
# 5              pl1-2             Blastoise     Rare Holo
# ...              ...                   ...           ...
# 15213  swsh11tg-TG24         Boss's Orders    Rare Ultra
# 15214     swsh11-200         Drapion VSTAR  Rare Rainbow
# 15215  swsh11tg-TG27                 Nessa    Rare Ultra
# 15217  swsh11tg-TG30              Mew VMAX   Rare Secret
# 15220     swsh11-216            Dark Patch   Rare Secret
#
#                         collection           series  holofoil_price  \
# ...

# %%
path="datas/price_history"
df=get_dataframe_cards_matrix(path)

# %%
k=0 #entre 0 et 1 sigmoid
x0=1 #entre 0 et 1 sigmoid
amount=300

# %%
df
# Out:
# Empty DataFrame
# Columns: [card_id, last_price, mean_return, Quantity Sold]
# Index: []

# %%
markowitz=MarkowitzOptimizer(amount,df,x0,k)

# %%
a=markowitz.get_streamlit_database_markowitz()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a=markowitz.get_streamlit_database_markowitz()
#
# File ~/GitProjects/Portfolio_Pokemon_Card/MarkowitzPortfolioOptimizer.py:140, in MarkowitzOptimizer.get_streamlit_database_markowitz(self, path_database)
#     139 def get_streamlit_database_markowitz(self, path_database="datas/pokemon_cards.csv"):
# --> 140     pokemon_cards_df=pd.read_csv(path_database)
#     141     total_investment, mean_return, df = self.optimize_cards_sell()
#     142     df['base_id'] = df['card_id'].str.split('_').str[0]
#
# ...

# %%
a[0], a[1]
# Out:
# (294.89, 0.131)

# %%
a[2]
# Out:
#                   id                name                     rarity  \
# 0             sm12-4        Vileplume-GX               Rare Holo GX
# 1          swsh1-203         Lapras VMAX               Rare Rainbow
# 2      swshp-SWSH150          Vaporeon V                      Promo
# 3         sv3pt5-196  Erika's Invitation                 Ultra Rare
# 4            sv2-199         Fletchinder          Illustration Rare
# 5   swsh12pt5gg-GG37      Simisear VSTAR            Rare Holo VSTAR
# 6            sv4-249     Iron Valiant ex  Special Illustration Rare
# 7             sv4-70       Iron Hands ex                Double Rare
# 8          swsh6-200       Blaziken VMAX               Rare Rainbow
# 9            sv2-269                Iono  Special Illustration Rare
# 10           sv1-251              Miriam  Special Illustration Rare
# 11         swsh1-200              Marnie                 Rare Ultra
# 12           xy12-11           Charizard                  Rare Holo
#
# ...
